# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardocarbo/NewRepo/blob/master/2022_12_04_Aplication_of_Machine_Learning_Methods_to_Real_World_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module Name: Machine Learning
#
# Module Code: MLEA_M
#
# Level: MSc.
#
# Programme: MSc Data Science
#
# Type of assessment: Coursework
#
# Weighting: 100%
#
# Max. mark available: 50
#
# BY: EDUARDO CARRILLO BOTERO
#
# Date: Friday, november 11th, 2022

# %% [markdown]
# # CHARGE FILES AND ANALYSIS DATA

# %%
#SETP 1: Instruction for open de Gooogle Drive in this virtual book, from Google Colab:
#-------------------------------------------------------------------------------
from google.colab import drive
drive.mount('/content/drive')
                                                        #BY : Eduardo_Carrillo_B
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #IMPORT PACKAGES

# %%
#Charge workfiles in Google Colab:
#-------------------------------------------------------------------------------
import pandas as pd                                                             # it help funtión in data analysis
import matplotlib.pyplot as plt                                                 #for create HD grafic
import numpy as np                                                              #use for master calculate
# %matplotlib inline

#Define the test_file and train_file and chage in GoogleColab
dtrain = pd.read_csv('/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/spam_dataset_train.csv')
dtest = pd.read_csv("/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/spam_dataset_test.csv")
                                                        #BY : Eduardo_Carrillo_B

# %% [markdown]
# #DATA STRUCTURE dtrain file

# %%
#Look the first rows in train file:
#-------------------------------------------------------------------------------
dtrain.head(10)
                                                        #BY : Eduardo_Carrillo_B
# Out:
#    email_id  word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0         0            1.61               0.00           0.00           0.0
# 1         1            0.34               0.00           1.70           0.0
# 2         2            0.00               0.00           0.37           0.0
# 3         3            0.00               0.22           0.00           0.0
# 4         4            0.00               0.00           0.00           0.0
# 5         5            0.00               0.00           0.00           0.0
# 6         6            0.00               0.00           0.00           0.0
# 7         7            0.29               0.00           0.29           0.0
# 8         8            0.00               0.72           0.00           0.0
# 9         9            0.00               0.00           0.38           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %% [markdown]
# #DATA STRUCTURE dtest file

# %%
#Look the first rows in test file:
#-------------------------------------------------------------------------------
dtest.head(10)
                                                        #BY : Eduardo_Carrillo_B
# Out:
#    email_id  word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0     10000            0.49               0.00           0.00           0.0
# 1     10001            0.00               0.00           1.29           0.0
# 2     10002            0.00               0.00           0.00           0.0
# 3     10003            0.97               0.00           0.00           0.0
# 4     10004            0.47               0.31           0.47           0.0
# 5     10005            0.00               0.00           0.00           0.0
# 6     10006            0.37               0.75           1.13           0.0
# 7     10007            0.50               0.25           0.42           0.0
# 8     10008            0.00               0.00           0.00           0.0
# 9     10009            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %% [markdown]
# #IF YOU ONLY USE JUPYTER

# %%
#Data Profiling with pandas_profiling (COMPILATE ONLY IN JUPYTER)
#-------------------------------------------------------------------------------
#from pandas_profiling import ProfileReport
                                                        #BY : Eduardo_Carrillo_B

# %%
#Profiling Analysis with Pandas_profiling (COMPILATE ONLY IN JUPYTER)
#-------------------------------------------------------------------------------
#report = ProfileReport(dtrain)
#report.to_widgets()
                                                        #BY : Eduardo_Carrillo_B

# %% [markdown]
# #COLUMNS IN DATASET (dtrain file)

# %%
#WHEN DO YOU USE OTHER PLATFORMS, YOU NEED START TO ANALYSIS DATA WITH: columns  in TEST FILE
#-------------------------------------------------------------------------------
dtrain.columns                                                                  #columns in dataset
                                                        #BY : Eduardo_Carrillo_B
# Out:
# Index(['email_id', 'word_freq_make', 'word_freq_address', 'word_freq_all',
#        'word_freq_3d', 'word_freq_our', 'word_freq_over', 'word_freq_remove',
#        'word_freq_internet', 'word_freq_order', 'word_freq_mail',
#        'word_freq_receive', 'word_freq_will', 'word_freq_people',
#        'word_freq_report', 'word_freq_addresses', 'word_freq_free',
#        'word_freq_business', 'word_freq_email', 'word_freq_you',
#        'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000',
#        'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george',
#        'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet',
#        'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85',
#        'word_freq_technology', 'word_freq_1999', 'word_freq_parts',
#        'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting',
#        'word_freq_original', 'word_freq_project', 'word_freq_re',
# ...

# %% [markdown]
# #COLUMNS IN DATASET (dtest file)

# %%
#WHEN DO YOU USE OTHER PLATFORMS, YOU NEED START TO ANALYSIS DATA WITH: columns in TEST FILE
#-------------------------------------------------------------------------------
dtest.columns                                                                  #columns in dataset
                                                        #BY : Eduardo_Carrillo_B
# Out:
# Index(['email_id', 'word_freq_make', 'word_freq_address', 'word_freq_all',
#        'word_freq_3d', 'word_freq_our', 'word_freq_over', 'word_freq_remove',
#        'word_freq_internet', 'word_freq_order', 'word_freq_mail',
#        'word_freq_receive', 'word_freq_will', 'word_freq_people',
#        'word_freq_report', 'word_freq_addresses', 'word_freq_free',
#        'word_freq_business', 'word_freq_email', 'word_freq_you',
#        'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000',
#        'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george',
#        'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet',
#        'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85',
#        'word_freq_technology', 'word_freq_1999', 'word_freq_parts',
#        'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting',
#        'word_freq_original', 'word_freq_project', 'word_freq_re',
# ...

# %% [markdown]
# #CHECK THE SHAPE OF THE DATAFRAME dtrain file

# %%
dtrain.shape                                                                    #sixe in train dataset
                                                         #By: Eduardo_Carrillo_B
# Out:
# (3220, 59)

# %% [markdown]
# ##CHECK THE SHAPE OF THE DATAFRAME dtest file

# %%
dtest.shape                                                                    #sixe in test dataset
                                                         #By: Eduardo_Carrillo_B
# Out:
# (1381, 58)

# %% [markdown]
# #IDENTIFY MISSING DATA.

# %%
#missing data in train dataset
#-------------------------------------------------------------------------------
dtrain.isna().sum().sort_values()
                                                         #By: Eduardo_Carrillo_B
# Out:
# email_id                      0
# word_freq_telnet              0
# word_freq_857                 0
# word_freq_data                0
# word_freq_415                 0
# word_freq_85                  0
# word_freq_technology          0
# word_freq_1999                0
# word_freq_parts               0
# word_freq_pm                  0
# word_freq_direct              0
# word_freq_cs                  0
# word_freq_meeting             0
# word_freq_labs                0
# word_freq_original            0
# word_freq_re                  0
# word_freq_edu                 0
# word_freq_table               0
# word_freq_conference          0
# char_freq_semicolon           0
# char_freq_bracket             0
# char_freq_sqbracket           0
# char_freq_excl                0
# char_freq_dollar              0
# char_freq_hash                0
# capital_run_length_average    0
# capital_run_length_longest    0
# word_freq_project             0
# capital_run_length_total      0
# ...

# %% [markdown]
# Not exist missing data in dtrain file

# %% [markdown]
# #ELIMINATION OF email_id COLUMN

# %%
#Elimination of training columns
#-------------------------------------------------------------------------------
X_train = dtrain.drop(columns=['email_id']).to_numpy()

#Selecting the target variable (outcome)
#-------------------------------------------------------------------------------
y_train = dtrain['email_id'].to_numpy()

#Remove Test ID column
#------------------------------------------------------------------------------
X_test = dtest.drop(columns='email_id').to_numpy()
                                                         #By: Eduardo_Carrillo_B

# %% [markdown]
# #DESCRIBE dtrain DATAFRAME

# %%
#Describe dtrain file with describe() comand
#-------------------------------------------------------------------------------
dtrain.describe()
                                                         #By: Eduardo_Carrillo_B
# Out:
#          email_id  word_freq_make  word_freq_address  word_freq_all  \
# count  3220.00000     3220.000000        3220.000000    3220.000000
# mean   1609.50000        0.108062           0.220792       0.288441
# std     929.67826        0.317388           1.313507       0.519689
# min       0.00000        0.000000           0.000000       0.000000
# 25%     804.75000        0.000000           0.000000       0.000000
# 50%    1609.50000        0.000000           0.000000       0.000000
# 75%    2414.25000        0.000000           0.000000       0.422500
# max    3219.00000        4.540000          14.280000       5.100000
#
#        word_freq_3d  word_freq_our  word_freq_over  word_freq_remove  \
# count   3220.000000    3220.000000     3220.000000       3220.000000
# mean       0.048587       0.312969        0.099031          0.113898
# std        1.137614       0.683362        0.261217          0.385296
# min        0.000000       0.000000        0.000000          0.000000
# ...

# %% [markdown]
# #DESCRIBE dtest DATAFRAME

# %%
#Analysis if exit null data
#-------------------------------------------------------------------------------
dtrain.isnull()
                                                         #By: Eduardo_Carrillo_B
# Out:
#       email_id  word_freq_make  word_freq_address  word_freq_all  \
# 0        False           False              False          False
# 1        False           False              False          False
# 2        False           False              False          False
# 3        False           False              False          False
# 4        False           False              False          False
# ...        ...             ...                ...            ...
# 3215     False           False              False          False
# 3216     False           False              False          False
# 3217     False           False              False          False
# 3218     False           False              False          False
# 3219     False           False              False          False
#
#       word_freq_3d  word_freq_our  word_freq_over  word_freq_remove  \
# 0            False          False           False             False
# ...

# %% [markdown]
# #IDENTIFY AND REMOVED OUTLIERS IN DATASET using BOXPLOT
#
# ---

# %%
#Identify Outliers (using boxplot)
#-------------------------------------------------------------------------------
for column in dtrain:
  plt.figure()
  dtrain.boxplot([column],vert=False)
  plt.show()
                                                         #By: Eduardo_Carrillo_B

# %% [markdown]
# In this case doesn`t use Scikit-learn for imput values  or missing values.

# %% [markdown]
# #IMPUTATION OUTLIERS #1

# %%
"""#REMOVE OUTLIERS
#-------------------------------------------------------------------------------
import scipy.stats as stats
z = np.abs(stats.zscore(dtrain))
# Solo mantenemos las filas con puntuación z menor que el valor absoluto de 3 
data_clean = dtrain[(z<3).all(axis=1)]
# Calculamos cuantas filas quedan
data_clean.shape"""
                                                         #By: Eduardo_Carrillo_B
# Out:
# '#REMOVE OUTLIERS\n#-------------------------------------------------------------------------------\nimport scipy.stats as stats\nz = np.abs(stats.zscore(dtrain))\n# Solo mantenemos las filas con puntuación z menor que el valor absoluto de 3 \ndata_clean = dtrain[(z<3).all(axis=1)]\n# Calculamos cuantas filas quedan\ndata_clean.shape'

# %%
#dtrain = data_clean

# %% [markdown]
# #BOXPLOT second round

# %%
"""#Identify Outliers (using boxplot) 
#-------------------------------------------------------------------------------
for column in dtrain:
  plt.figure()
  dtrain.boxplot([column],vert=False)
  plt.show()"""
                                                         #By: Eduardo_Carrillo_B
# Out:
# '#Identify Outliers (using boxplot) \n#-------------------------------------------------------------------------------\nfor column in dtrain:\n  plt.figure()\n  dtrain.boxplot([column],vert=False)\n  plt.show()'

# %%
#dtrain = data_clean

# %% [markdown]
# #HISTOGRAM

# %%
plot1 = dtrain.hist(figsize=[20,20])    # displays histograms of the DataFrame columns

# %%
#correlation matrix
#-------------------------------------------------------------------------------
corr = dtrain.corr ()
corr.style.background_gradient (cmap = 'coolwarm')
                                                    #By: Eduardo Carrillo Botero
# Out:
# <style type="text/css">
# ...

# %%
#Number of empty fields in the training and test files:
#-------------------------------------------------------------------------------
dtrain.isna().sum()
                                                     #By Eduardo Carrillo Botero
# Out:
# email_id                      0
# word_freq_make                0
# word_freq_address             0
# word_freq_all                 0
# word_freq_3d                  0
# word_freq_our                 0
# word_freq_over                0
# word_freq_remove              0
# word_freq_internet            0
# word_freq_order               0
# word_freq_mail                0
# word_freq_receive             0
# word_freq_will                0
# word_freq_people              0
# word_freq_report              0
# word_freq_addresses           0
# word_freq_free                0
# word_freq_business            0
# word_freq_email               0
# word_freq_you                 0
# word_freq_credit              0
# word_freq_your                0
# word_freq_font                0
# word_freq_000                 0
# word_freq_money               0
# word_freq_hp                  0
# word_freq_hpl                 0
# word_freq_george              0
# word_freq_650                 0
# ...

# %%
#Percentage of gaps in the data columns
#-------------------------------------------------------------------------------
n_obs_train = dtrain.shape[0]
print ("Num Obs =", n_obs_train)
dtrain.isna().sum()/n_obs_train
                                                    #By: Eduardo Carrillo Botero
# Out:
# Num Obs = 3220
# email_id                      0.0
# word_freq_make                0.0
# word_freq_address             0.0
# word_freq_all                 0.0
# word_freq_3d                  0.0
# word_freq_our                 0.0
# word_freq_over                0.0
# word_freq_remove              0.0
# word_freq_internet            0.0
# word_freq_order               0.0
# word_freq_mail                0.0
# word_freq_receive             0.0
# word_freq_will                0.0
# word_freq_people              0.0
# word_freq_report              0.0
# word_freq_addresses           0.0
# word_freq_free                0.0
# word_freq_business            0.0
# word_freq_email               0.0
# word_freq_you                 0.0
# word_freq_credit              0.0
# word_freq_your                0.0
# word_freq_font                0.0
# word_freq_000                 0.0
# word_freq_money               0.0
# word_freq_hp                  0.0
# word_freq_hpl                 0.0
# ...

# %%
#Delete training columns
#-------------------------------------------------------------------------------
X_train = dtrain.drop(columns=['email_id','spam']).to_numpy()


#Variable selection spam (outcome)
#-------------------------------------------------------------------------------
y_train = dtrain['spam'].to_numpy()

#Empty email_id dtest column:
#-------------------------------------------------------------------------------
X_test = dtest.drop(columns='email_id').to_numpy()
X_test = dtest.drop(columns='email_id').to_numpy()
                                                   #By: Eduardo Carrillo Botero

# %%
#Imputation of missing values ​​by the mean(average) of the data
#-------------------------------------------------------------------------------
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='mean').fit(X_train)

X_train = imp.transform(X_train)
X_test = imp.transform(X_test)
                                                    #By: Eduardo Carrillo Botero

#dtrain column size
#-------------------------------------------------------------------------------
Nobstest = X_test.shape[0] 
print(Nobstest)
                                                    #By: Eduardo Carrillo Botero

#Scaling the data
#-------------------------------------------------------------------------------
from sklearn import preprocessing

mm_scaler = preprocessing.StandardScaler() #.
X_train = mm_scaler.fit_transform(X_train)
X_test = mm_scaler.fit_transform(X_test)
                                                                                                     
Nobstest = X_train.shape[0] 
print(Nobstest)
                                                    #By: Eduardo Carrillo Botero
# Out:
# 1381
# 3220

# %% [markdown]
# #Regresion Lineal

# %%
#Import the required package: 
from sklearn.linear_model import LogisticRegressionCV

log_reg_model = LogisticRegressionCV(penalty = 'l2',
                               scoring = 'roc_auc',
                               solver = 'sag',
                               Cs = 10)

# %%
#Model training via the "fit" function
log_reg_model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %% [markdown]
# #Vectores de Soporte (Support Vector Machine SVM)
# Support vector analysis

# %%
#Importación del paquete de Support Vector Machine
from sklearn.svm import SVC

svc = SVC(C = 1, kernel = 'linear')
svc.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
#Tunning de los hiperparametros a través del modulo Grid_search
from sklearn.model_selection import GridSearchCV

#Selección del valor C optimo
tunned_parameters = [{'C' : [0.001, 0.01, 0.1, 1, 5, 10, 15, 100]}]
svc = GridSearchCV(SVC(kernel='linear',probability=True), tunned_parameters, cv = 5, scoring='roc_auc')
svc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(kernel='linear', probability=True),
#              param_grid=[{'C': [0.001, 0.01, 0.1, 1, 5, 10, 15, 100]}],
#              scoring='roc_auc')

# %%
#Se revisan los resultados del modelo
svc.cv_results_
                                                    #By: Eduardo Carrillo Botero
# Out:
# {'mean_fit_time': array([ 1.15623093,  0.77171249,  0.7132154 ,  1.38344593,  3.61366177,
#          6.98837605, 10.71708989, 60.79035444]),
#  'std_fit_time': array([0.01701007, 0.05212063, 0.03592783, 0.13512967, 0.158222  ,
#         0.86673631, 2.25066536, 4.97130028]),
#  'mean_score_time': array([0.04104152, 0.02510691, 0.01921821, 0.01785321, 0.01607509,
#         0.01613264, 0.01694999, 0.01600785]),
#  'std_score_time': array([0.00305946, 0.00118572, 0.00107349, 0.00191713, 0.00050973,
#         0.00037406, 0.00167349, 0.00037554]),
#  'param_C': masked_array(data=[0.001, 0.01, 0.1, 1, 5, 10, 15, 100],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 0.001},
#   {'C': 0.01},
#   {'C': 0.1},
#   {'C': 1},
#   {'C': 5},
#   {'C': 10},
#   {'C': 15},
#   {'C': 100}],
#  'split0_test_score': array([0.93154498, 0.94462287, 0.95460998, 0.9598955 , 0.96223119,
# ...

# %%
#Busqueda de los mejores parámetros
svc.best_params_
# Out:
# {'C': 15}

# %%
Nobstrain = X_train.shape[0]
Nobstest = X_test.shape[0]
print("Test=",Nobstest)
print("Train=",Nobstrain)
# Out:
# Test= 1381
# Train= 3220

# %%
#File Prediction
y_test_svc = svc.predict_proba(X_test)

Nobssolv = y_test_svc.shape[0]
print(Nobssolv)

dset_sol_svc = pd.DataFrame({"email_id" : dtest.email_id, "Predicted" : y_test_svc[:,1]})

dset_sol_svc.to_csv("/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/predictions_linear.csv", index=False)
                                                     #By:Eduardo Carrillo Botero
# Out:
# 1381

# %% [markdown]
# #Random Forest

# %%
#Import package for random forest
from sklearn.ensemble import RandomForestClassifier

#Hyper parameter tuning
RandForest_hyp_grid = {'max_features' : [0.2, 0.3, 0.5, 0.7],
                       'min_samples_leaf' : range(3,9,3)}

#Execution of all parameters
model_randforest = GridSearchCV(RandomForestClassifier(), param_grid = RandForest_hyp_grid, cv = 5, scoring='roc_auc').fit(X_train, y_train)

#Best parameters
model_randforest.best_params_
# Out:
# {'max_features': 0.2, 'min_samples_leaf': 3}

# %%
#Generation of the prediction
y_test_randforest = model_randforest.predict_proba(X_test)

#Creating the file
dset_solv_randforest = pd.DataFrame({"email_id" : dtest.email_id, "Predicted" : y_test_randforest[:,1]})
dset_solv_randforest.to_csv("/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/predictions_Forest.csv", index=False)

# %%
dtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 59 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   email_id                    3220 non-null   int64
#  1   word_freq_make              3220 non-null   float64
#  2   word_freq_address           3220 non-null   float64
#  3   word_freq_all               3220 non-null   float64
#  4   word_freq_3d                3220 non-null   float64
#  5   word_freq_our               3220 non-null   float64
#  6   word_freq_over              3220 non-null   float64
#  7   word_freq_remove            3220 non-null   float64
#  8   word_freq_internet          3220 non-null   float64
#  9   word_freq_order             3220 non-null   float64
#  10  word_freq_mail              3220 non-null   float64
#  11  word_freq_receive           3220 non-null   float64
#  12  word_freq_will              3220 non-null   float64
# ...

# %%
model_randforest.score(X_train, y_train)
# Out:
# 0.9983482636123743

# %% [markdown]
# Model evaluation (Random Forest)

# %% [markdown]
# Use the roc_auc_curve to estimate the AUC of the above

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import roc_curve

# %%
#Intentando crear la curva ROC
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('RAMDOM FOREST Receiver Operating Characteristic Curve')
    plt.legend()
    plt.show()
    
dtrain, cls_lab = make_classification(n_samples=2100, n_classes=2, weights=[1,1], random_state=2)
train_X, test_X, train_y, test_y = train_test_split(dtrain, cls_lab, test_size=0.5, random_state=2)

model =RandomForestClassifier()
model.fit(train_X, train_y)

prob = model.predict_proba(test_X)
prob = prob[:, 1]
fper, tper, thresholds = roc_curve(test_y, prob)
plot_roc_curve(fper, tper)

# %%
from sklearn.metrics import PrecisionRecallDisplay

PrecisionRecallDisplay.from_estimator(model, test_X, test_y)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cutoff = y_train.mean() # Choose the cutoff based on the prevalence of the positive class
# New predicted labels:
y_newlabels = (lr_probs>=cutoff).astype(int)
ConfusionMatrixDisplay.from_predictions(y_test, y_newlabels)

# %% [markdown]
# #GBM

# %%
##import the GBM package
from sklearn.ensemble import GradientBoostingClassifier

#Hyperparameters for boosting
gbm_hyp_grid = {'learning_rate':[0.001, 0.01, 0.1, 0.3, 0.5],
                'min_samples_split' : range(2,20,2)}

#Ejecución de los hiperparametros
model_gbm = GridSearchCV(GradientBoostingClassifier(), param_grid=gbm_hyp_grid, cv= 5, scoring='roc_auc').fit(X_train, y_train)

#View to the best parameters
model_gbm.best_params_
# Out:
# {'learning_rate': 0.3, 'min_samples_split': 18}

# %%
#Generation of the result
y_test_gbm = model_gbm.predict_proba(X_test)

#Creating results file
dset_solv_gbm = pd.DataFrame({"email_id" : dtest.email_id, "Predicted" : y_test_gbm[:,1]})
dset_solv_gbm.to_csv("/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/predictions_GBM.csv", index=False)

# %%
#Creating the curve ROC
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('CBM Receiver Operating Characteristic Curve')
    plt.legend()
    plt.show()
    
dtrain, cls_lab = make_classification(n_samples=2100, n_classes=2, weights=[1,1], random_state=2)
train_X, test_X, train_y, test_y = train_test_split(dtrain, cls_lab, test_size=0.5, random_state=2)

model = GradientBoostingClassifier()
model.fit(train_X, train_y)

prob = model.predict_proba(test_X)
prob = prob[:, 1]
fper, tper, thresholds = roc_curve(test_y, prob)
plot_roc_curve(fper, tper)

# %%
from sklearn.metrics import PrecisionRecallDisplay

PrecisionRecallDisplay.from_estimator(model, test_X, test_y)

# %% [markdown]
# #EXTRA TREE

# %%
##import the Extra Tree package
from sklearn.ensemble import ExtraTreesClassifier

#hiper parameters tunning
ExtraTrees_hyp_grid = {'max_features' : [0.001,0.01, 0.1, 0.3, 0.7],
                       'min_samples_leaf' : range(3,18,3)}

#Execution of all parameters
model_ExtraTrees = GridSearchCV(ExtraTreesClassifier(), param_grid = ExtraTrees_hyp_grid, cv = 5, scoring='roc_auc').fit(X_train, y_train)

#improve parameters
model_ExtraTrees.best_params_
# Out:
# {'max_features': 0.3, 'min_samples_leaf': 3}

# %%
#Generation of the prediction
y_test_ExtraTrees = model_ExtraTrees.predict_proba(X_test)

#Creating fila
dset_solv_ExtraTrees = pd.DataFrame({"email_id" : dtest.email_id, "Predicted" : y_test_ExtraTrees[:,1]})
dset_solv_ExtraTrees.to_csv("/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/predictions_ExtraTrees.csv", index=False)

# %%
#Import the package for Decision Trees
from sklearn.tree import DecisionTreeClassifier

#Hyper parameter tuning
DecisionTree_hyp_grid = {'max_features' : [0.001,0.1, 0.3, 0.5, 0.7],
                       'min_samples_leaf' : range(3,18,3)}

#Execution of all parameters
model_DecisionTree = GridSearchCV(DecisionTreeClassifier(), param_grid = DecisionTree_hyp_grid, cv = 5, scoring='roc_auc').fit(X_train, y_train)

#Best parameters
model_DecisionTree.best_params_
# Out:
# {'max_features': 0.5, 'min_samples_leaf': 15}

# %%
#Generation of the prediction
y_test_DecisionTree = model_DecisionTree.predict_proba(X_test)

#creating the file
dset_solv_ExtraTrees = pd.DataFrame({"email_id" : dtest.email_id, "Predicted" : y_test_ExtraTrees[:,1]})
dset_solv_ExtraTrees.to_csv("/content/drive/MyDrive/ESCUELA_ING MLEA_M/PROYECTO DE CLASE #0/predictions_DecisionTree.csv", index=False)

# %%
print("RANDON FOREST Score: ")
model_randforest.score(X_train, y_train)
# Out:
# RANDON FOREST Score:
# 0.9983482636123743

# %%
print("GBM Score: ")
model_gbm.score(X_train, y_train)
# Out:
# GBM Score:
# 0.9981156388681104

# %%
print("EXTRA TREE Score: ")
model_ExtraTrees.score(X_train, y_train)
# Out:
# EXTRA TREE Score:
# 0.9985029439618068

# %%
print("DECISION TREE Score: ")
model_DecisionTree.score(X_train, y_train)
# Out:
# DECISION TREE Score:
# 0.9841291516467616
