# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardocarbo/NewRepo/blob/master/PLATZI_Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__ #Para mirar que versión de pandas se tiene
# Out:
# '1.3.5'

# %%
# !pip install --upgrade pandas #Para tener la última versión de Pandas

# %%
#Para crear un diccionario
dict_data ={'CO':300,'CH':200,'MX':400}
dict_data
# Out:
# {'CH': 200, 'CO': 300, 'MX': 400}

# %%
#Para traer elementos específicos de ese diccionario 
pd.Series(dict_data)
# Out:
# CO    300
# CH    200
# MX    400
# dtype: int64

# %%
#Se va hacer o modificar el diccionario con una lsita de elementos
dict_data = {'CH':[100,800,200],'CO':[100,200,300],'MX':[300,500,400]}
dict_data
# Out:
# {'CH': [100, 800, 200], 'CO': [100, 200, 300], 'MX': [300, 500, 400]}

# %%
#Generamos un Data Frame con el diccionario anterormente creado
df = pd.DataFrame(dict_data)
df
# Out:
#     CH   CO   MX
# 0  100  100  300
# 1  800  200  500
# 2  200  300  400

# %%
#Ahora, utilizamos otro diccionario que va utilizar la libreria de numpy
import numpy as np #Librería para análisis numérico

# %%
dict_data = {
    'edad'  :[10,9,13,14,12,11,12],
    'cm'    :[115,110,130,155,125,120,125],
    'pais'  :['CO','MX','CO','MX','MX','CH','CH'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1'    :[5,10,8,np.nan,7,8,3],
    'Q2'    :[7,9,9,8,8,8,9.]
}
dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9.0],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['CO', 'MX', 'CO', 'MX', 'MX', 'CH', 'CH']}

# %%
df =pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   CO      M   5.0  7.0
# 1     9  110   MX      F  10.0  9.0
# 2    13  130   CO      F   8.0  9.0
# 3    14  155   MX      M   NaN  8.0
# 4    12  125   MX      M   7.0  8.0
# 5    11  120   CH      M   8.0  8.0
# 6    12  125   CH      F   3.0  9.0

# %%
df =pd.DataFrame(dict_data, index=['ana','benito','camilo','daniel','erika','fabian','gabriela'])
df
# Out:
#           edad   cm pais genero    Q1   Q2
# ana         10  115   CO      M   5.0  7.0
# benito       9  110   MX      F  10.0  9.0
# camilo      13  130   CO      F   8.0  9.0
# daniel      14  155   MX      M   NaN  8.0
# erika       12  125   MX      M   7.0  8.0
# fabian      11  120   CH      M   8.0  8.0
# gabriela    12  125   CH      F   3.0  9.0

# %%
df.index
# Out:
# Index(['ana', 'benito', 'camilo', 'daniel', 'erika', 'fabian', 'gabriela'], dtype='object')

# %%
df.columns
# Out:
# Index(['edad', 'cm', 'pais', 'genero', 'Q1', 'Q2'], dtype='object')

# %%
df.values
# Out:
# array([[10, 115, 'CO', 'M', 5.0, 7.0],
#        [9, 110, 'MX', 'F', 10.0, 9.0],
#        [13, 130, 'CO', 'F', 8.0, 9.0],
#        [14, 155, 'MX', 'M', nan, 8.0],
#        [12, 125, 'MX', 'M', 7.0, 8.0],
#        [11, 120, 'CH', 'M', 8.0, 8.0],
#        [12, 125, 'CH', 'F', 3.0, 9.0]], dtype=object)

# %%
df['edad']
# Out:
# ana         10
# benito       9
# camilo      13
# daniel      14
# erika       12
# fabian      11
# gabriela    12
# Name: edad, dtype: int64

# %%
df[['edad','cm','Q1']]
# Out:
#           edad   cm    Q1
# ana         10  115   5.0
# benito       9  110  10.0
# camilo      13  130   8.0
# daniel      14  155   NaN
# erika       12  125   7.0
# fabian      11  120   8.0
# gabriela    12  125   3.0

# %%
df.loc['ana',['edad','cm','Q1']]
# Out:
# edad     10
# cm      115
# Q1      5.0
# Name: ana, dtype: object

# %%
df.loc[['ana','erika'],['edad','cm','Q1']]
# Out:
#        edad   cm   Q1
# ana      10  115  5.0
# erika    12  125  7.0

# %%
df.loc['daniel','Q1']
# Out:
# nan

# %%
df
# Out:
#           edad   cm pais genero    Q1   Q2
# ana         10  115   CO      M   5.0  7.0
# benito       9  110   MX      F  10.0  9.0
# camilo      13  130   CO      F   8.0  9.0
# daniel      14  155   MX      M   NaN  8.0
# erika       12  125   MX      M   7.0  8.0
# fabian      11  120   CH      M   8.0  8.0
# gabriela    12  125   CH      F   3.0  9.0

# %%
df.iloc[2,1]
# Out:
# 130

# %%
df.iloc[2,[1,3]]
# Out:
# cm        130
# genero      F
# Name: camilo, dtype: object

# %%
df.iloc[[2,4,5],[1,3]]
# Out:
#          cm genero
# camilo  130      F
# erika   125      M
# fabian  120      M

# %%
df.iloc[:,[1,3]]
# Out:
#            cm genero
# ana       115      M
# benito    110      F
# camilo    130      F
# daniel    155      M
# erika     125      M
# fabian    120      M
# gabriela  125      F

# %%
df['edad']>=12
# Out:
# ana         False
# benito      False
# camilo       True
# daniel       True
# erika        True
# fabian      False
# gabriela     True
# Name: edad, dtype: bool

# %%
df[df['edad']>=12]
# Out:
#           edad   cm pais genero   Q1   Q2
# camilo      13  130   CO      F  8.0  9.0
# daniel      14  155   MX      M  NaN  8.0
# erika       12  125   MX      M  7.0  8.0
# gabriela    12  125   CH      F  3.0  9.0

# %%
df[(df['edad']>=12)&(df['pais']=='MX')]
# Out:
#         edad   cm pais genero   Q1   Q2
# daniel    14  155   MX      M  NaN  8.0
# erika     12  125   MX      M  7.0  8.0

# %%
df.query('edad>12')
# Out:
#         edad   cm pais genero   Q1   Q2
# camilo    13  130   CO      F  8.0  9.0
# daniel    14  155   MX      M  NaN  8.0

# %%
df[df['Q2']>=df['Q1']]
# Out:
#           edad   cm pais genero   Q1   Q2
# ana         10  115   CO      M  5.0  7.0
# camilo      13  130   CO      F  8.0  9.0
# erika       12  125   MX      M  7.0  8.0
# fabian      11  120   CH      M  8.0  8.0
# gabriela    12  125   CH      F  3.0  9.0
