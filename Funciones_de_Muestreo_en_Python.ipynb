# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardocarbo/NewRepo/blob/master/Funciones_de_Muestreo_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import io

# %% [markdown]
# ### Leemos la base de datos atrabajar en la muestra ruta de origen

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-86276739-abfe-4a63-b44b-2d07af72daa7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86276739-abfe-4a63-b44b-2d07af72daa7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
econdata = pd.read_csv(io.BytesIO(uploaded["Econdata.csv"]))

# %%
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# ...

# %% [markdown]
# ###Funciones de Muestre:

# %% [markdown]
# ### 1) Muestreo aleatorio simple:

# %%
aleat_8 = econdata.sample(n=8)
aleat_8
# Out:
#       id                  geo_point_2d  \
# 3      3      19.42489472,-99.12073393
# 192  192  19.4313325389,-99.1497520491
# 28    28  19.4256899299,-99.1400384748
# 131  131  19.4389531509,-99.1479144659
# 194  194  19.4288786806,-99.1456731565
# 184  184  19.4306993983,-99.1389056387
# 110  110  19.4356877258,-99.1387888649
# 80    80  19.4313297575,-99.1416730617
#
#                                              geo_shape   clave_cat  \
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 192  {"type": "MultiPoint", "coordinates": [[-99.14...  002_052_04
# 28   {"type": "MultiPoint", "coordinates": [[-99.14...  001_076_17
# 131  {"type": "MultiPoint", "coordinates": [[-99.14...  003_080_06
# 194  {"type": "MultiPoint", "coordinates": [[-99.14...  002_060_04
# 184  {"type": "MultiPoint", "coordinates": [[-99.13...  001_043_01
# 110  {"type": "MultiPoint", "coordinates": [[-99.13...  001_003_11
# 80   {"type": "MultiPoint", "coordinates": [[-99.14...  002_028_04
#
# ...

# %%
aleat_8_2 =econdata.sample(n=8)#
aleat_8_2
# Out:
#       id                  geo_point_2d  \
# 81    81      19.42262452,-99.15107339
# 117  117  19.4253041176,-99.1405962735
# 206  206  19.4298259264,-99.1386360482
# 99    99  19.4438918423,-99.1402516182
# 63    63  19.4339116282,-99.1468371035
# 100  100  19.4337759404,-99.1378211234
# 95    95  19.4370305998,-99.1214093113
# 89    89  19.4373498816,-99.1421604061
#
#                                              geo_shape   clave_cat  \
# 81   {"type": "MultiPoint", "coordinates": [[-99.15...  002_096_02
# 117  {"type": "MultiPoint", "coordinates": [[-99.14...  001_078_03
# 206  {"type": "MultiPoint", "coordinates": [[-99.13...  001_047_36
# 99   {"type": "MultiPoint", "coordinates": [[-99.14...  003_052_18
# 63   {"type": "MultiPoint", "coordinates": [[-99.14...  002_015_07
# 100  {"type": "MultiPoint", "coordinates": [[-99.13...  001_014_06
# 95   {"type": "MultiPoint", "coordinates": [[-99.12...  318_114_01
# 89   {"type": "MultiPoint", "coordinates": [[-99.14...  003_096_04
#
# ...

# %%
prop_25 = econdata.sample(frac = 0.25)
prop_25.head()
# Out:
#       id                  geo_point_2d  \
# 220  220   19.4331382067,-99.125997696
# 188  188  19.4281241134,-99.1460742157
# 111  111  19.4430614318,-99.1353793874
# 166  166  19.4394422606,-99.1501035229
# 128  128  19.4270781084,-99.1210175514
#
#                                              geo_shape        clave_cat  \
# 220  {"type": "MultiPoint", "coordinates": [[-99.12...       006_008_08
# 188  {"type": "MultiPoint", "coordinates": [[-99.14...       002_067_08
# 111  {"type": "MultiPoint", "coordinates": [[-99.13...       004_107_02
# 166  {"type": "MultiPoint", "coordinates": [[-99.15...       012_153_08
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
#
#               delegacion perimetro     tipo        nom_id
# 220            Cuautémoc         A    Hotel  México Nuevo
# 188            Cuautémoc         B    Hotel      Manolo 1
# 111            Cuautémoc         B    Hotel   Embajadores
# 166            Cuautémoc         B    Hotel         Polly
# ...

# %% [markdown]
# ### Muestreo Sistemático:

# %%
def systematic_sampling(econdata,step):
  indexes = np.arange(0,len(econdata),step=step)
  systematic_sample = econdata.iloc[indexes]
  return systematic_sample

systematic_sample = systematic_sampling(econdata,3)
systematic_sample
# Out:
#       id                  geo_point_2d  \
# 0      0   19.424781053,-99.1327537959
# 3      3      19.42489472,-99.12073393
# 6      6      19.43553422,-99.12324801
# 9      9  19.4407152937,-99.1498060057
# 12    12      19.43990186,-99.14813347
# ..   ...                           ...
# 216  216  19.4247697438,-99.1249707246
# 219  219  19.4234096295,-99.1438351156
# 222  222   19.4397905042,-99.134628735
# 225  225      19.43094655,-99.12455418
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat  \
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6    {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9    {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# ..                                                 ...         ...
# ...
